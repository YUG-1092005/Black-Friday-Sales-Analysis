# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Yug Trivedi\Desktop\Data Science_GFG\DataAnalyst\DataAnalyst Project\BlacFriday Sales\Black_Friday_Sales.txt.txt")
df.to_csv("Black_Friday_Sales.csv")
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %% [markdown]
# ## Checking info of dataset

# %%
df.info()

# %% [markdown]
# ## Checking null values in  dataset

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %% [markdown]
# ## Option one to handle the null values column

# %%
rounded_num = round(df["Product_Category_2"].mean(), 1)
df["Product_Category_2"] = df["Product_Category_2"].fillna(rounded_num)
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
rounded_num = round(df["Product_Category_3"].mean(), 1)
df["Product_Category_3"] = df["Product_Category_3"].fillna(rounded_num)
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %% [markdown]
# ## Second Option is deleting the column

# %%
del df["Product_Category_2"]
del df["Product_Category_2"]

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %% [markdown]
# ## Analyzing the columns

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_3  Purchase
# 0                 NaN      8370
# 1                14.0     15200
# 2                 NaN      1422
# 3                 NaN      1057
# 4                 NaN      7969

# %%
print(df["User_ID"].unique())
print("-"*90)
print(len(df["User_ID"].unique()))
# Out:
# [1000001 1000002 1000003 ... 1004113 1005391 1001529]
# ------------------------------------------------------------------------------------------
# 5891

# %%
print(df["Product_ID"].unique())
print("-"*90)
print(len(df["Product_ID"].unique()))
# Out:
# ['P00069042' 'P00248942' 'P00087842' ... 'P00038842' 'P00295642'
#  'P00091742']
# ------------------------------------------------------------------------------------------
# 3623

# %%
print(df["Gender"].unique())
print("-"*90)
print(len(df["Gender"].unique()))
# Out:
# ['F' 'M']
# ------------------------------------------------------------------------------------------
# 2

# %%
print(df["Occupation"].unique())
print("-"*90)
print(len(df["Occupation"].unique()))
# Out:
# [10 16 15  7 20  9  1 12 17  0  3  4 11  8 19  2 18  5 14 13  6]
# ------------------------------------------------------------------------------------------
# 21

# %%
print(df["City_Category"].unique())
print("-"*90)
print(len(df["City_Category"].unique()))
# Out:
# ['A' 'C' 'B']
# ------------------------------------------------------------------------------------------
# 3

# %%
print(df["Stay_In_Current_City_Years"].unique())
print("-"*90)
print(len(df["Stay_In_Current_City_Years"].unique()))
# Out:
# ['2' '4+' '3' '1' '0']
# ------------------------------------------------------------------------------------------
# 5

# %%
print(df["Marital_Status"].unique())
print("-"*90)
print(len(df["Marital_Status"].unique()))
# Out:
# [0 1]
# ------------------------------------------------------------------------------------------
# 2

# %%
print(df["Product_Category_1"].unique())
print("-"*90)
print(len(df["Product_Category_1"].unique()))
# Out:
# [ 3  1 12  8  5  4  2  6 14 11 13 15  7 16 18 10 17  9]
# ------------------------------------------------------------------------------------------
# 18

# %%
print(df["Product_Category_3"].unique())
print("-"*90)
print(len(df["Product_Category_3"].unique()))
# Out:
# [nan 14. 17.  5.  4. 16. 15.  8.  9. 13.  6. 12.  3. 18. 11. 10.]
# ------------------------------------------------------------------------------------------
# 16

# %%
print(df["Purchase"].unique())
print("-"*90)
print(df["Purchase"].sum())
# Out:
# [ 8370 15200  1422 ... 14539 11120 18426]
# ------------------------------------------------------------------------------------------
# 5017668378

# %% [markdown]
# ## Analyzing the product gender

# %%
data = pd.DataFrame({"Ratio": [len(df[df["Gender"] == "M"]), len(df[df["Gender"] == "F"])]}, index=["Male","Female"])
data.plot.pie(y="Ratio", autopct="%.2f", title = 'Male Female Ratio(%)')
# Out:
# <Axes: title={'center': 'Male Female Ratio(%)'}, ylabel='Ratio'>

# %%
df.groupby("Gender").size()
# Out:
# Gender
# F    132197
# M    405380
# dtype: int64

# %%
df.groupby("Gender").size().plot(kind="pie", title="Male Female Ratio(%)", autopct="%.2f")
# Out:
# <Axes: title={'center': 'Male Female Ratio(%)'}>

# %%
df.groupby("Gender").size().plot(kind="bar", title="Male Female Ratio")
# Out:
# <Axes: title={'center': 'Male Female Ratio'}, xlabel='Gender'>

# %%
df.groupby("Gender")["Purchase"].sum()
# Out:
# Gender
# F    1164624021
# M    3853044357
# Name: Purchase, dtype: int64

# %%
df.groupby("Gender")["Purchase"].sum().plot(kind="pie", autopct="%.2f", title="Purchase of Male and Female(%)")
# Out:
# <Axes: title={'center': 'Purchase of Male and Female(%)'}, ylabel='Purchase'>

# %%
fig, axes = plt.subplots(1,2, figsize=(10,5))

purchase_data = df.groupby("Gender")["Purchase"].mean()

purchase_data.plot(kind="bar", ax=axes[0], title="Purchase per Male and Female", color=["pink", "blue"])
axes[0].set_ylabel("Amount of Purchases")

purchase_data.plot(kind="pie", ax=axes[1], title="Purchase per Male and Female(%)", autopct="%.2f")
axes[1].set_ylabel("")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Analyzing in which age people are more buying and which marital status people are more buying

# %%
df.groupby("Age").size
# Out:
# <bound method GroupBy.size of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x000001F1055BB8C0>>

# %%
df.groupby("Age").size().plot(kind="bar", title="Age group buying more products")
plt.ylabel("Age group no.")
# Out:
# Text(0, 0.5, 'Age group no.')

# %%
df.groupby("Age")["Product_ID"].count()
# Out:
# Age
# 0-17      14707
# 18-25     97634
# 26-35    214690
# 36-45    107499
# 46-50     44526
# 51-55     37618
# 55+       20903
# Name: Product_ID, dtype: int64

# %%
lst = []

for i in df["Age"].unique():
    lst.append([i,df[df["Age"] == i]["Product_ID"].nunique()])

data = pd.DataFrame(lst, columns=["Age", "Products"])
data
# Out:
#      Age  Products
# 0   0-17      2300
# 1    55+      2573
# 2  26-35      3419
# 3  46-50      3099
# 4  51-55      2877
# 5  36-45      3318
# 6  18-25      3213

# %%
data.plot.bar(x="Age")
plt.ylabel("Products per age")
# Out:
# Text(0, 0.5, 'Products per age')

# %%
df.groupby("Age")["Purchase"].sum().plot(kind="bar", title="Age group buying more products")
plt.ylabel("Purchase amount per age")
# Out:
# Text(0, 0.5, 'Purchase amount per age')

# %%
df.groupby("Age")["Purchase"].mean().plot(kind="pie", title="Avg.purcahse per age", autopct="%.2f")
# Out:
# <Axes: title={'center': 'Avg.purcahse per age'}, ylabel='Purchase'>

# %%
df.groupby("Marital_Status").size().plot(kind="pie", title="Marital Status(%)", autopct="%.2f")
# Out:
# <Axes: title={'center': 'Marital Status(%)'}>

# %% [markdown]
# ## Handling more columns and comparing

# %%
sns.countplot(x="Age", data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x="Age",hue="Gender",data=df)
plt.ylabel("No. of customers")
# Out:
# Text(0, 0.5, 'No. of customers')

# %%
sns.countplot(x="Age",hue="City_Category",data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x="Age",hue="Gender",data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x="City_Category",hue="Gender",data=df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(x = df['City_Category'])
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby("City_Category")["Purchase"].sum().plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby("City_Category")["Purchase"].mean().plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: ylabel='Purchase'>

# %%
sns.countplot(x="Stay_In_Current_City_Years", data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x="Stay_In_Current_City_Years", hue="City_Category", data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x="Stay_In_Current_City_Years", hue="Gender", data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x = 'Stay_In_Current_City_Years', hue = 'Marital_Status', data = df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
df.groupby("City_Category")["Purchase"].sum().plot(kind="bar",title="City category having the highest purchase")
# Out:
# <Axes: title={'center': 'City category having the highest purchase'}, xlabel='City_Category'>

# %%
df.groupby("City_Category")["Purchase"].mean().plot(kind="bar",title="City category having the avg purchase")
# Out:
# <Axes: title={'center': 'City category having the avg purchase'}, xlabel='City_Category'>

# %%
sns.countplot(x = df['Occupation'])
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby("Occupation").size().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby("Occupation")["Purchase"].sum().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby("Occupation")["Purchase"].mean().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
sns.countplot(x = 'Occupation', hue = 'Marital_Status', data = df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(x = 'Occupation', hue = 'Gender', data = df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby("Occupation")["Product_ID"].nunique().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Product_Category_1').sum()['Purchase'].sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby('Product_Category_1').mean()['Purchase'].sort_values().plot(kind = 'bar')
